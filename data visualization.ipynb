# %%
import matplotlib.pyplot as plt
import numpy as np
y1=np.array([3,8,1,10])
y2=np.array([6,2,5,11])
plt.plot(y1)

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.title('sports watch data')
plt.xlabel('ave pulse')
plt.ylabel('calorie burnage')
plt.plot(x,y)
plt.grid(color='green',linestyle='--',linewidth=1.5)
plt.show()

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,1,2)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,1,3)
plt.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15312/405252201.py in <module>
#      11 x=np.array([0,1,2,3])
#      12 y=np.array([3,8,1,10])
# ---> 13 plt.subplot(2,1,3)
#      14 plt.plot(x,y)
#      15 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1270
#    1271     # First, search for an existing subplot with a matching spec.
# -> 1272     key = SubplotSpec._from_subplot_args(fig, args)
#    1273
#    1274     for ax in fig.axes:
#
# ~\anaconda3\lib\site-packages\matplotlib\gridspec.py in _from_subplot_args(figure, args)
#     651                     num = int(num)
#     652                 if num < 1 or num > rows*cols:
# --> 653                     raise ValueError(
#     654                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#     655                 i = j = num
#
# ValueError: num must be 1 <= num <= 2, not 3

# %%
x=np.array([1,2])
y=np.array([5,10])
plt.plot(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('relation between x and y',loc='left',color='blue')
plt.grid(color='red')
plt.show()
